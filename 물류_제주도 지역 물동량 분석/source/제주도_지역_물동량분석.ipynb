# %% [markdown]
# ## **제주도 지역 물동량 분석**
# ---
# > **목차(Context)**
#
# * 프로젝트 Summary
# * 문제상황 Introduction
# * Process01
# * Process02
# * Process03

# %% [markdown]
# ## 프로젝트 Summary
# ---
# > **프로젝트명**
# ```
# 제주도 지역 물동량 분석
# ```
# > **프로젝트유형**
# ```
# 데이터 EDA 및 가설검증/인사이트 도출
# ```
# > **학습목표**
# ```
# - 데이터를 Read하고 전처리할 수 있는 역량 습득
# - 분석 목적에 맞는 가설을 수립하고 인사이트를 추출할 수 있는 역량 습득
# ```

# %% [markdown]
# ## **문제상황 Introduction**
# ---
# > **시나리오**
# ```
# A 물류업체는 상/하차 과정에서 물품 파손 등에 대한 고객 클레임 건수가 증가하고 있다. 물품의 특성마다 조심해야하는 부분이 다르기 때문에 여간 힘든 일이 아니다. 따라서 A사는 물품이 많이 배송되는 지역들을 구분하고 용도에 맞는 적절한 택배차량을 선정하여 배송을 운영하려고 한다.
# ```
# > **문제정의**
# ```
# 상품 배송 고객 Claim건수 증가, 물품 파손 건수 증가
# ```
# > **기대효과**
# ```
# 고객 Claim건수 감소, 물품 파손 건수 감소
# ```
# > **해결방안**
# ```
# 지역별 물품 배송량 분석을 통해 적정 차량 배차 및 직원 교육
# ```
# > **성과측정**
# ```
# 배송 운영 후 Claim건수 모니터링
# ```
# > **운영**
# ```
# - 지역별 물품 배송 특성 추출 및 배차
# - 직원 교육을 통한 고객 Claim 감소 활동
# ```

# %% [markdown]
# > **데이터 살펴보기**
#
# * 출발지 정보인 '송하인_격자공간고유번호', 도착지 정보인 '수하인_격자공간고유번호' 가 있고, 물품 카테고리별 건수가 적재되어 있음

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
# Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# %%
# Data read
import pandas as pd

df= pd.read_csv('../data/S_PJT09_DATA.csv',encoding='cp949')
df.head()
# Out:
#    index      송하인_격자공간고유번호      수하인_격자공간고유번호 물품_카테고리  운송장_건수
# 0      0  5011000595017300  2871000192069300      음반       3
# 1      1  4148000690043300  5011000264024400   문화컨텐츠       3
# 2      2  5011000078068400  1120000007005400     농산물       3
# 3      3  4127100048006400  5011000587019400    기타식품       7
# 4      4  5011000078068400  2823700010076300     농산물       3

# %% [markdown]
# ### **Process01**
# ### **-유통량EDA**

# %% [markdown]
# #### ∙ Data 전처리
# ---
# * 수집된 데이터의 기본 정보들을 확인
#
#     (1) Data shape(형태) 확인
#
#     (2) Data type 확인
#
#     (3) Null값 확인(* 빈 값의 Data)
#
#     (4) Outlier 확인(* 정상적인 범주를 벗어난 Data)

# %%
# Data 형태 확인
print('df :' , df.shape)
# 31684 row ,5 cols
# Out:
# df : (31684, 5)

# %%
# Data type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31684 entries, 0 to 31683
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         31684 non-null  int64
#  1   송하인_격자공간고유번호  31684 non-null  int64
#  2   수하인_격자공간고유번호  31684 non-null  int64
#  3   물품_카테고리       31684 non-null  object
#  4   운송장_건수        31684 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 1.2+ MB

# %%
# Null 값 확인
print(df.isnull().sum())
# Out:
# index           0
# 송하인_격자공간고유번호    0
# 수하인_격자공간고유번호    0
# 물품_카테고리         0
# 운송장_건수          0
# dtype: int64

# %%
# Outlier 확인
df.describe()
# Out:
#               index  송하인_격자공간고유번호  수하인_격자공간고유번호        운송장_건수
# count  31684.000000  3.168400e+04  3.168400e+04  31684.000000
# mean   15841.500000  4.648814e+15  3.801369e+15      4.879308
# std     9146.527301  8.341336e+14  1.314660e+15      6.756473
# min        0.000000  1.111000e+15  1.111000e+15      3.000000
# 25%     7920.750000  4.713000e+15  2.826000e+15      3.000000
# 50%    15841.500000  5.011000e+15  4.159000e+15      3.000000
# 75%    23762.250000  5.013001e+15  5.011000e+15      5.000000
# max    31683.000000  5.013001e+15  5.013001e+15    413.000000

# %%
df.columns[1]
# Out:
# '송하인_격자공간고유번호'

# %% [markdown]
# #### **• 배송 지역 탐색**
# ---

# %%
df.head()
# Out:
#    index      송하인_격자공간고유번호      수하인_격자공간고유번호 물품_카테고리  운송장_건수
# 0      0  5011000595017300  2871000192069300      음반       3
# 1      1  4148000690043300  5011000264024400   문화컨텐츠       3
# 2      2  5011000078068400  1120000007005400     농산물       3
# 3      3  4127100048006400  5011000587019400    기타식품       7
# 4      4  5011000078068400  2823700010076300     농산물       3

# %%
# # Col rename
df.columns=['index','start','end','prod','cnt']
df.head()
# Out:
#    index             start               end   prod  cnt
# 0      0  5011000595017300  2871000192069300     음반    3
# 1      1  4148000690043300  5011000264024400  문화컨텐츠    3
# 2      2  5011000078068400  1120000007005400    농산물    3
# 3      3  4127100048006400  5011000587019400   기타식품    7
# 4      4  5011000078068400  2823700010076300    농산물    3

# %%
# 출발지 숫자 4229개
df['start'].nunique()
# Out:
# 4229

# %%
# 도착지 숫자 26875
df['end'].nunique()

# 출발지보다 배송지의 지역이 더 많음
# Out:
# 26875

# %%
# 총지역(출발+배송) 30,455개
all_list=list(df['start'])+list(df['end'])
unique_list=set(all_list)
len(unique_list)
# Out:
# 30455

# %%
unique_list
# Out:
# {4719000594022400,
#  5011000214028300,
#  4122000314073100,
#  5013000824029200,
#  5011000376033300,
#  3120000056033300,
#  4211000611045400,
#  3171000366006300,
#  5011000252039200,
#  4413300201095200,
#  4711300747100200,
#  5013000782086200,
#  4571000461066300,
#  2820000048087100,
#  4122000267018300,
#  2915500014043200,
#  4128100085006400,
#  4157000301019200,
#  2623000014094400,
#  5011000365023300,
#  5011000219009100,
#  4157000294072400,
#  1123000009097300,
#  5011000263049300,
#  1129000019034200,
#  4833000458027100,
#  5013000822063200,
#  4275000609079400,
#  4128700034056300,
#  5011000214028400,
#  4425000028078200,
#  5013000809087100,
#  5011000075092100,
#  4617000425095300,
#  5013000862040200,
#  1147000011096200,
#  5011000319017100,
#  1120000002097300,
#  2611000004051100,
#  4150000377004200,
#  5011000527028400,
#  4119500019073200,
#  2818500004020400,
#  4161000274002100,
#  5011000263049400,
#  4128700010070200,
#  1171000013095100,
#  4812900072030400,
#  5013000822063300,
#  5013000749056200,
#  1171000030003400,
#  4613000291025100,
#  4139000123097300,
#  4211000714068200,
#  4887000136024300,
#  5011000319017200,
#  4119500010029300,
#  2611000004051200,
#  2911000015012100,
#  1171000026071300,
#  1174000024027400,
#  5011000379048200,
#  5013000740012300,
#  4117100027052300,
#  4148000435077400,
#  4146300038021400,
#  4136000074023200,
#  4413300066091300,
#  5013000822063400,
#  5011000315085100,
#  4150000291021100,
#  4128100161028400,
#  5011000368038200,
#  4122000263086400,
#  1156000017023300,
#  4128100022092100,
#  5011000266064200,
#  4420000288080200,
#  2820000002081100,
#  5013000862040400,
#  4611000043045200,
#  4127100043002200,
#  2635000046027100,
#  1129000024015200,
#  1165000003027300,
#  4611000045011300,
#  4139000017060200,
#  4513000185004400,
#  4117300019069300,
#  4425000033059200,
#  5011000315085200,
#  2871000141005200,
#  4136000258048400,
#  5011000632017300,
#  3017000035025300,
#  4519000284070300,
#  4111100029043100,
#  1126000017015200,
#  1165000008008100,
#  5011000266064300,
#  2826000012018100,
#  5011000319017400,
#  4613000411087300,
#  4136000210076100,
#  2818500038099400,
#  2653000007025100,
#  4159000286069200,
#  5011000379048400,
#  2623000022090200,
#  5011000373019100,
#  5011000109040100,
#  4157000244003300,
#  3114000001008100,
#  2714000144073200,
#  3020000111100400,
#  2729000004092400,
#  4219000120017400,
#  4315000333009400,
#  4776000669090300,
#  4418000111010300,
#  4719000529011200,
#  5011000721015300,
#  4128700028027400,
#  4824000477004300,
#  4420000288080400,
#  5011000524014100,
#  4728000770081300,
#  5011000215077400,
#  5011000260035100,
#  4521000324039200,
#  4313000600011300,
#  1129000024015400,
#  1165000017052200,
#  4139000017060400,
#  3014000006005300,
#  4111300010050100,
#  4117300011074100,
#  5011000519033400,
#  1150000041034300,
#  4113300003095100,
#  4145000034075200,
#  2729000033059400,
#  1168000024052300,
#  2823700024001100,
#  4413300184056400,
#  4833000421065300,
#  5011000315085400,
#  4812500221035100,
#  3111000027038300,
#  5011001116066400,
#  1117000018035300,
#  4377000274035300,
#  4213000353088100,
#  2914000038003300,
#  1111000017011300,
#  2917000094024300,
#  1141000002077300,
#  1135000023073400,
#  4615000535073400,
#  4183000576033400,
#  5013000055030400,
#  4617000397046400,
#  4137000016020100,
#  5013000732017300,
#  4713000861041300,
#  2826000108094100,
#  2824500033094300,
#  2729000040006300,
#  4480000298058400,
#  3014000013083300,
#  4833000419099300,
#  4159000302060200,
#  4711300728095400,
#  4182000627090100,
#  4146100378010300,
#  4679000218010300,
#  4715000843076300,
#  5013000759018200,
#  4219000121066200,
#  4571000261051100,
#  5013000817083100,
#  4812100195058400,
#  3017000016020200,
#  4141000017052400,
#  4139000098063100,
#  4833000375059200,
#  3111000032019200,
#  4519000407016200,
#  5011000373019400,
#  4157000081081100,
#  5013000579056400,
#  2820000036029200,
#  5013000910013200,
#  2653000016069400,
#  4717000827077400,
#  1111000015045400,
#  4215000346002200,
#  5011000478008100,
#  5011000713020200,
#  3014000009020200,
#  1147000010048300,
#  1156000023053100,
#  5011000214029100,
#  4128700020032300,
#  4161000246084400,
#  1159000012096300,
#  4146500025058100,
#  2917000057062200,
#  3171000366007100,
#  4146300026094400,
#  5013000817083200,
#  3023000068031300,
#  1117000005059400,
#  4279000643011400,
#  4514000451011400,
#  4420000327009100,
#  5011000318100300,
#  4127100042085200,
#  4825000086078300,
#  2826000108094300,
#  4155000425022300,
#  4421000419083100,
#  4113500002059100,
#  4373000373011300,
#  2723000075027300,
#  4418000365028200,
#  4111100034024300,
#  5013000014005100,
#  5011000263050100,
#  4111300048061300,
#  5011000380097400,
#  1150000020063100,
#  1129000005010300,
#  2644000026002300,
#  1171000030004100,
#  1162000002057100,
#  5011000214029200,
#  1156000023053200,
#  3014000016098200,
#  1162000004023200,
#  2620000007095200,
#  4111300037051300,
#  4121000004027300,
#  4413300201096100,
#  5013000817083300,
#  4161000402060200,
#  4127100035007400,
#  5013000480097200,
#  2623000021042100,
#  1129000023098300,
#  4117300025099200,
#  5011000174052300,
#  4148000699057100,
#  4213000358069200,
#  2917000068072400,
#  4161000142013400,
#  4111300048061400,
#  5013000895071200,
#  4136000118064100,
#  4729000162100200,
#  4611000033084400,
#  4415000760026100,
#  1171000023057400,
#  4812300017075200,
#  4213000369079300,
#  1123000007001100,
#  2917000051033100,
#  4511300085089300,
#  4711100265006100,
#  2920000093029400,
#  4211000929027100,
#  4117100011062300,
#  5013000709080100,
#  4139000098063400,
#  4511100022031400,
#  5013000740013100,
#  1126000014001200,
#  4371000527029300,
#  5011000219010100,
#  2811000051074100,
#  4687000035001400,
#  4281000455046200,
#  4146300060042300,
#  2641000064091200,
#  4167000299013200,
#  4213000345093200,
#  5011000265016400,
#  4128500005078100,
#  4680000311002200,
#  4157000290010200,
#  4276000688047200,
#  4812300017075300,
#  1162000004023400,
#  4420000327009400,
#  5013000906081400,
#  2826000115041400,
#  5011000268031100,
#  1154500002055300,
#  4511300065035400,
#  1165000025048200,
#  5011000379049100,
#  5013000636073100,
#  5011000578016400,
#  4121000007042200,
#  4128100137043100,
#  1165000012072100,
#  1171000013096100,
#  5011000330028200,
#  4136000309036200,
#  5011000212063400,
#  4136000258049200,
#  4812300002002100,
#  2826000098002100,
#  2720000007079100,
#  3020000113067200,
#  2641000046003400,
#  4157000166016200,
#  5011000860083400,
#  4782000423044300,
#  5011000266065100,
#  4122000066086100,
#  4141000023082200,
#  2824500032046300,
#  5011001002034400,
#  4119700002047200,
#  2814000003024100,
#  5011000379049200,
#  2871000263034100,
#  4511300050093300,
#  2726000014001400,
#  5011000894031100,
#  5011000219010300,
#  4420000330024200,
#  4182000628008200,
#  1165000012072200,
#  4148000546096400,
#  5013000867022100,
#  4159000208082200,
#  5011000264099100,
#  4136000260015400,
#  5013000809088300,
#  5011000266065200,
#  4155000306009400,
#  4150000118007100,
#  5011000319018300,
#  1165000003028300,
#  4611000045012300,
#  4136000358057300,
#  2635000039081300,
#  4518000350070100,
#  2917000060077400,
#  4717000826029400,
#  5011000115070300,
#  4163000192075100,
#  2635000019027300,
#  4159000383063400,
#  4165000715044200,
#  1174000025077100,
#  4111300034037100,
#  4617000122058100,
#  4113500056061300,
#  1111000023041400,
#  5011000315086200,
#  4713000284063100,
#  5011000228054400,
#  5011000264099200,
#  4377000156071300,
#  4425000051017100,
#  4139000117069200,
#  4311300061005200,
#  5011000215078300,
#  2820000033015200,
#  4141000023082400,
#  5011000379049400,
#  4375000123049400,
#  1162000007038400,
#  5011000373020100,
#  4213000381007300,
#  4415000823072200,
#  4415000537073100,
#  5013000579057100,
#  1135000034084300,
#  4145000014022100,
#  5011000264099300,
#  4131000019060200,
#  4180000467060200,
#  4719000587077100,
#  4825000436041200,
#  2826000136013300,
#  5013000619034100,
#  1120000001050100,
#  4136000259098100,
#  4615000690001400,
#  4783000023074300,
#  4817000493090300,
#  2817000013039100,
#  4420000355059200,
#  5011000215078400,
#  4272001313015300,
#  3014000004040200,
#  4155000358045200,
#  3111000016029200,
#  3117000039073300,
#  2650000009070100,
#  4131000008050200,
#  4773000713078300,
#  4136000086083100,
#  2920000021071400,
#  5011000373020200,
#  5013000725071400,
#  5011000204068400,
#  1114000004089400,
#  4511300097017400,
#  4717000827078200,
#  5013000867022400,
#  5011000315086400,
#  5011000264099400,
#  4157000127088200,
#  4148000358008400,
#  5013000728086100,
#  4311300075030100,
#  4150000116041300,
#  4831000342038100,
#  4159000672077400,
#  1171000031053400,
#  4812100195059300,
#  4874000210069100,
#  1156000018073200,
#  4514000400025200,
#  1144000016025200,
#  1165000019019400,
#  5011000373020300,
#  5013000271038100,
#  2818500034037400,
#  2820000029083300,
#  4713000071071400,
#  4831000253040300,
#  4272000723060400,
#  4719000587077300,
#  5011000353097400,
#  5011000435017400,
#  4511100019017400,
#  3014000024094400,
#  4825000421099200,
#  2826000012019400,
#  4148000359057100,
#  2914000025028300,
#  4691000209049300,
#  4427000222058200,
#  4155000403003100,
#  5011000262002400,
#  4155000425023200,
#  1171000012048100,
#  4377000013072100,
#  4418000387049200,
#  1153000002029300,
#  4161000413071100,
#  1171000021092100,
#  2914000030009100,
#  4213000353089300,
#  5011000309057300,
#  3023000068032300,
#  4150000154052400,
#  5013000870037300,
#  1171000010082100,
#  4111300008085300,
#  2818500008085300,
#  1168000007014200,
#  2641000061077300,
#  2638000021047100,
#  3011000053008200,
#  4145000026081100,
#  2914000012052300,
#  4182000421046100,
#  4373000344045400,
#  4825000301037400,
#  4157000163002200,
#  4150000099002200,
#  5011000571070300,
#  5011000851040100,
#  2917000084064100,
#  5011000265017200,
#  2871000302094200,
#  2826000128018300,
#  3120000056035200,
#  4127100055062400,
#  2920000024086400,
#  4119500016060300,
#  5013000817084300,
#  1121500005009300,
#  3120000058001300,
#  4882000550037400,
#  5013000276019100,
#  4427000449075100,
#  4157000212023200,
#  4711300764010400,
#  5011000312072100,
#  1153000014088100,
#  1165000011024300,
#  3017000003045300,
#  4111300048062400,
#  1156000021088200,
#  4119500007016400,
#  5011000374069200,
#  4817000565049300,
#  4889000069040100,
#  2653000012007400,
#  5013000868071400,
#  5011000434100200,
#  4128100008069100,
#  1150000038021100,
#  4888000638093300,
#  2653000035076100,
#  2920000056068100,
#  1153000014088200,
#  2671000069081100,
#  4372000464046100,
#  4127300050094100,
#  5011000174053400,
#  5011000219011100,
#  5013000014006300,
#  4812300030052400,
#  4311300051044400,
#  1123000011065400,
#  4613000262060100,
#  1111000016095300,
#  5011000434100300,
#  4311300060088400,
#  5011000319019100,
#  1156000010078300,
#  2917000073054300,
#  1159000008034400,
#  4127100020066400,
#  3120000161024100,
#  5011000217045100,
#  1153000014088300,
#  4413100205017200,
#  4773000288012400,
#  1171000026073200,
#  4511100058077300,
#  4831000236001400,
#  4514000130017400,
#  5011000314038400,
#  2711000007051400,
#  1117000008075400,
#  1144000019040400,
#  2818500027091100,
#  1162000002058400,
#  4480000080087200,
#  1171000015063200,
#  5011000368040100,
#  4719000411048100,
#  5011000317053100,
#  4157000166017200,
#  2771000053074100,
#  2641000053082300,
#  2729000044071100,
#  5013000782088400,
#  5013000012040400,
#  4157000146094300,
#  2717000015022300,
#  1129000017070300,
#  5011000967039200,
#  4511100001061100,
#  3017000033061100,
#  5013000565033200,
#  1165000012073200,
#  4613000619100400,
#  3111000033069300,
#  4128700041005300,
#  5011000315087100,
#  2635000043014400,
#  5011000264100100,
#  4311300061006100,
#  1165000016005400,
#  5011000266066200,
#  1135000023075100,
#  1156000002083100,
#  4725001075034400,
#  2626000011004200,
#  1121500013005100,
#  1120000011012400,
#  1168000006097200,
#  4141000003029300,
#  4481000272038200,
#  5013000740014400,
#  1162000007039300,
#  5011000219011400,
#  4146300001061200,
#  4684000588073300,
#  4511100023081300,
#  4121000001014100,
#  5011000366074200,
#  4729000045054300,
#  5013000867023200,
#  3017000035027300,
#  1156000015059300,
#  5011000264100200,
#  4128100015016300,
#  4313000473004400,
#  3611000340089200,
#  5013000574077300,
#  5011000266066300,
#  4615000690002300,
#  4137000022051200,
#  4213000590068100,
#  4139000097016200,
#  2714000170027400,
#  4217000056064400,
#  2632000034048400,
#  4311100063091100,
#  4127300042099100,
#  2714000157051300,
#  4111500010064300,
#  2635000055073200,
#  4165000715045300,
#  2920000088050100,
#  1135000034085300,
#  4182000628009400,
#  5011000366074300,
#  4479000091036100,
#  4812300016028100,
#  5011000315087300,
#  4161000297073100,
#  5011000169073100,
#  5011000264100300,
#  3020000127093200,
#  1165000008010200,
#  4131000021027300,
#  1153000013040100,
#  4161000343079400,
#  4613000367049200,
#  2820000049007100,
#  4812100182084100,
#  5011001054071300,
#  2635000062020100,
#  5011000415095300,
#  4148000500091400,
#  5013000468040200,
#  4776000674073100,
#  5011000373021200,
#  4128500032080400,
#  4157000213072400,
#  5013000579058200,
#  2920000088050200,
#  1156000022006300,
#  2820000022006300,
#  4113500048067100,
#  5011000366074400,
#  1171000022010400,
#  5013000668056100,
#  5011000315087400,
#  4111700004047400,
#  1171000007068200,
#  2826000039021100,
#  5011000264100400,
#  2917000072006200,
#  5011000435018300,
#  4115000009034300,
#  5013000927054400,
#  4127300011035200,
#  2826000136014400,
#  1165000015088200,
#  4420000355060300,
#  4511300086008400,
#  1111000026057300,
#  1165000017054300,
#  4119500018027100,
#  3120000124062300,
#  4613000287095400,
#  5011000373021300,
#  4128100042017400,
#  5011000506059400,
#  3114000017001100,
#  2817000026016400,
#  5011000169073300,
#  5011000309058200,
#  1135000008002200,
#  4111700020038300,
#  2720000001051300,
#  4217000077036200,
#  1156000025021100,
#  2617000004029100,
#  2917000028097200,
#  2717000005061300,
#  4127300027026100,
#  2871000217029300,
#  4831000329063100,
#  4311300062055100,
#  1174000008039100,
#  4128500008094400,
#  3020000072043200,
#  4113100018027200,
#  5013000819051200,
#  3017000009075400,
#  2711000006003400,
#  2614000010005200,
#  4163000133094100,
#  2818500012018400,
#  1171000014015200,
#  4111500004035300,
#  5011000968088300,
#  2635000042097400,
#  4773000716094200,
#  5011000309058300,
#  4128700020034300,
#  1121500003044100,
#  4159000247012100,
#  5011000112057100,
#  4159000344005400,
#  2917000095075100,
#  3023000053091100,
#  2714000156003100,
#  4111300008086300,
#  5011000540007200,
#  4117100026006300,
#  4580000056085300,
#  1156000005098300,
#  2917000068074300,
#  4420000336055100,
#  1144000003050300,
#  1123000009100100,
#  4511100046019400,
#  1114000005008200,
#  1150000042085200,
#  1171000030006100,
#  4146300053097300,
#  4313000361069400,
#  4145000030014300,
#  4822000217099100,
#  5011000214031200,
#  4311300044098400,
#  4219000259087200,
#  4119500014095200,
#  4824000469011300,
#  5011000720100200,
#  4146500025060200,
#  4128700036025200,
#  5011000134077300,
#  2914000017034100,
#  5013000817085300,
#  4127300027026300,
#  5013000032095100,
#  1135000017046400,
#  1114000001076100,
#  5011000172088200,
#  4122000105016200,
#  4113100018027400,
#  4311300033088400,
#  3011000053009300,
#  2917000082099100,
#  5011000423091100,
#  4418000387050400,
#  1174000017083300,
#  2823700016008100,
#  3171000384097200,
#  5011000374070200,
#  3017000094010300,
#  4182000732081100,
#  4281001582005200,
#  2717000012008400,
#  4128100103097300,
#  1162000004025300,
#  4812100187065300,
#  4119700008078300,
#  5011000201055200,
#  5013000906083300,
#  2826000115043300,
#  4213000334085100,
#  4375000233020400,
#  4827000403004400,
#  5011000312073200,
#  2826000124087300,
#  5011000219012100,
#  4127300016016400,
#  4136000060001300,
#  1171000021093400,
#  5011000265018400,
#  4729000098008100,
#  5011000214031400,
#  4122000314076200,
#  4159000247012400,
#  2920000105090100,
#  2917000080002100,
#  4111700014009400,
#  4688000431033400,
#  1135000009051200,
#  4148000690015300,
#  1138000007007300,
#  4183000489004100,
#  1171000010083400,
#  1150000031075400,
#  2726000012037200,
#  3017000001080400,
#  1153000014089300,
#  5011000379051100,
#  4111100026031200,
#  4480000166071400,
#  2823700016008300,
#  4717000371080300,
#  4511300052061300,
#  4125000075054200,
#  5013000822066300,
#  1171000030006400,
#  3171000664067200,
#  5013000272088200,
#  4513000320011400,
#  1129000006061200,
#  5011000266067100,
#  3171000438099100,
#  4128500043091100,
#  5011000215080100,
#  1147000011099300,
#  5011000319020200,
#  4278000697085100,
#  1117000013057200,
#  1120000002100400,
#  2650000001076400,
#  4121000020020400,
#  4833000205061300,
#  4165000728022200,
#  1159000002006200,
#  4128100121054400,
#  4514000379055300,
#  5013000667008200,
#  2614000009088200,
#  4833000420019400,
#  5011000219012300,
#  4136000234065100,
#  2824500041092300,
#  2638000008072400,
#  5011000226090200,
#  1150000034090200,
#  2729000004095200,
#  5011000352050400,
#  2638000046083300,
#  5013000867024100,
#  4682001221029100,
#  4371000104062200,
#  4825000136019200,
#  4715000301096200,
#  2729000008027400,
#  4122000301100300,
#  2917000067026200,
#  2611000004054300,
#  1159000002006300,
#  1171000026074400,
#  4831000308092200,
#  4117300019072300,
#  3011000061005100,
#  5011000219012400,
#  2914000020049200,
#  4713000672038200,
#  4165000715046200,
#  4113500056063300,
#  2729000013008200,
#  3023000014032200,
#  1171000015064400,
#  5013000854048100,
#  2641000045088100,
#  5011000215080300,
#  1138000021032300,
#  5011000319020400,
#  2826000123039100,
#  2914000018083200,
#  4139000017063300,
#  5013000754040200,
#  5011000379051400,
#  2614000018001300,
#  5013000865058200,
#  4139000077094300,
#  4137000033062300,
#  2817000010026400,
#  2638000024063400,
#  1171000007069100,
#  1144000013012400,
#  4223000679026100,
#  4719000411049400,
#  4719000587079100,
#  3611000340090300,
#  4211000648011200,
#  1121500011040200,
#  4678000237088200,
#  4613000314097100,
#  5011000215080400,
#  1171000002088400,
#  2726000055029200,
#  4148000667078100,
#  2911000035069400,
#  5011000422043100,
#  4128500008095200,
#  4111300016082400,
#  3011000061005300,
#  5011000138010100,
#  4613000340049400,
#  4122000151023100,
#  5013000623099400,
#  4511300097019400,
#  3114000008089100,
#  4827000369057300,
#  1168000004001300,
#  1156000009031200,
#  5013000883015200,
#  5013000171032100,
#  4139000095051300,
#  4615000600088100,
#  4315000620060200,
#  4139000022044200,
#  2629000021020200,
#  4825000312049200,
#  4121000026050100,
#  3020000027086400,
#  4136000210079300,
#  5011000371056200,
#  4113500010057300,
#  2820000020041300,
#  1168000022089300,
#  4141000019021400,
#  1165000019021400,
#  2726000013086300,
#  3611000345071200,
#  4115000036036200,
#  2826000112029300,
#  4111300021063300,
#  3611000363028100,
#  4511100019019400,
#  2911000011083400,
#  4873000051019400,
#  4128500044009100,
#  5011000311025300,
#  4776000723095200,
#  4128700029079200,
#  1111000026058400,
#  4217000070090400,
#  4111100032061100,
#  4146100243009200,
#  5011000373022400,
#  1130500013035200,
#  2635000027025100,
#  4115000036036300,
#  2817000018022100,
#  5011000169074400,
#  4511300076048100,
#  4111700020039400,
#  4687000301080300,
#  4711100087013100,
#  3117000044056300,
#  2620000007098100,
#  4873000353009400,
#  5011000378003200,
#  1171000010084100,
#  4513000220004100,
#  4682000636055300,
#  5011000422043400,
#  4713000464027400,
#  4817000489029400,
#  4111300010053400,
#  2638000023015200,
#  1144000025071400,
#  1168000016060200,
#  5011001115021100,
#  1114000005009200,
#  5011000265019200,
#  4113500035092300,
#  5013000817086300,
#  4136000040079200,
#  2826000137064300,
#  2632000020025200,
#  4146100139069300,
#  4111300024078200,
#  4831000236003200,
#  4480000166072200,
#  2820000050057100,
#  5011001115021200,
#  4111100019085200,
#  4572000511070100,
#  3014000007057300,
#  4159000340074400,
#  5011000374071200,
#  3011000084074400,
#  5013000236044200,
#  4481000100073400,
#  1121500005011400,
#  1156000010080200,
#  4129000007012300,
#  5011000312074200,
#  4146100139069400,
#  4128100099035100,
#  1171000012050400,
#  4128100085010400,
#  5011000314040300,
#  2644000164024300,
#  5011000381018100,
#  5011000263053300,
#  3171000384098300,
#  4122000298086400,
#  4159000245047300,
#  4822000217100300,
#  1171000001040400,
#  4159000216080400,
#  ...}

# %% [markdown]
# #### **• 물품 카테고리 검색**
# ---

# %%
# 총 100개의 물품 목록
df['prod'].nunique()
# Out:
# 100

# %%
df['prod'].value_counts().head(30)
# Out:
# prod
# 농산물          20321
# 문화컨텐츠         1091
# 음료            1034
# 수산             860
# 가공식품           846
# 기타식품           698
# 건강식품           591
# 음반             576
# 축산             383
# 냉동/간편조리식품      375
# 과자             320
# 생활용품           318
# 반려동물           315
# 주방용품           300
# 상의             294
# 기타패션의류         236
# 기타디지털/가전       220
# 스킨케어           205
# 문구/사무용품        167
# 건강용품           162
# 아우터            155
# 하의             150
# 기저귀/물티슈        130
# 기타화장품/미용       102
# 공구              95
# 다이어트식품          92
# 의료용품            82
# 인테리어소품          72
# 신발              70
# 취미용품            66
# Name: count, dtype: int64

# %%
# 운솓장 건수 기준, 내림차순 정렬
df_cnt=df.groupby('prod',as_index=False)['cnt'].sum()
df_cnt=df_cnt.sort_values(by=['cnt'],ascending=False)
df_cnt.head(30)
# Out:
#          prod    cnt
# 27        농산물  87829
# 66         음료   5890
# 3        가공식품   5766
# 34      문화컨텐츠   5429
# 51         수산   4880
# 17       기타식품   4250
# 5        건강식품   3413
# 80         축산   3385
# 19     기타패션의류   3042
# 67         음반   2357
# 11         과자   1866
# 25  냉동/간편조리식품   1787
# 77       주방용품   1776
# 44       생활용품   1599
# 6        건강용품   1554
# 15   기타디지털/가전   1505
# 36       반려동물   1388
# 33    문구/사무용품   1280
# 21   기타화장품/미용   1111
# 41         상의   1090
# 54       스킨케어   1070
# 69       의료용품    792
# 14    기저귀/물티슈    711
# 56         신발    637
# 29     다이어트식품    619
# 57        아우터    547
# 10         공구    532
# 83       취미용품    525
# 93         하의    496
# 23         낚시    386

# %%
# 운송장 건수 기준, 내림차순 정렬 Plotting

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['dark_background'])

plt.rc('font',family='AppleGothic')
plt.bar(df_cnt['prod'][0:30],df_cnt['cnt'][0:30] , label='cnt');
plt.xticks(rotation=-20);
plt.gcf().set_size_inches(25,5);

# %%
# 운송장 건수 기준, 내림차순 정렬 Plotting(* 농산물 제거)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use(['dark_background'])
plt.rc('font',family='AppleGothic')

# 막대 그래프 위치 변경을 원하면 plt.barh 함수 사용
plt.bar(df_cnt['prod'][1:30],df_cnt['cnt'][1:30],label='cnt');
plt.xticks(rotation=-90);
plt.gcf().set_size_inches(25,5);

# %% [markdown]
# ### **Process02**
# #### - 지역별 유통량 탐색

# %%
df.head()
# Out:
#    index             start               end   prod  cnt
# 0      0  5011000595017300  2871000192069300     음반    3
# 1      1  4148000690043300  5011000264024400  문화컨텐츠    3
# 2      2  5011000078068400  1120000007005400    농산물    3
# 3      3  4127100048006400  5011000587019400   기타식품    7
# 4      4  5011000078068400  2823700010076300    농산물    3

# %% [markdown]
# #### • 출발지/도착지 분석
# ---

# %%
# 가장 많이 배송이 출발되는 지역
df['start'].value_counts()
# Out:
# start
# 5011000078068400    3882
# 5013000610049100    1790
# 5013000731055200    1235
# 5011000137030100    1137
# 5013000821028200     731
#                     ...
# 4511300030055300       1
# 4719000321023400       1
# 4423000423020300       1
# 4711300748080100       1
# 2811000139076100       1
# Name: count, Length: 4229, dtype: int64

# %%
# 출발지 기준 상위 500개의 장소에서 전체 배송건수에 80% 가량을 조달함
df['start'].value_counts().head(500).sum()/df['start'].value_counts().sum()
# Out:
# 0.7936182300214619

# %%
# 가장 많이 배송이 도착되는 지역
df['end'].value_counts()
# Out:
# end
# 5013000635005300    35
# 5011000543041100    33
# 5011000314069300    33
# 5011000544072300    30
# 5011000318044100    30
#                     ..
# 5011000109040100     1
# 4183000550093100     1
# 4425000028078200     1
# 1147000011064300     1
# 5011000263065200     1
# Name: count, Length: 26875, dtype: int64

# %%
df['end'].value_counts().sum()
# Out:
# 31684

# %%
# 도착지 기준 상위 약 20,000 개의 장소에서 전체 배송건수에 80%가량을 조달함

df['end'].value_counts().head(20500).sum()/df['end'].value_counts().sum()
# Out:
# 0.7987943441484661

# %%
df_start_end=pd.DataFrame({'start' : df['start'].value_counts(),'end':df['end'].value_counts()})
df_start_end.fillna(0,inplace=True)
df_start_end['total']=df_start_end['start']+df_start_end['end']
df_start_end.head()
# Out:
#                   start  end  total
# 1111000004097200    0.0  1.0    1.0
# 1111000005062300    0.0  1.0    1.0
# 1111000005067400    0.0  1.0    1.0
# 1111000007059100    0.0  1.0    1.0
# 1111000007071100    0.0  1.0    1.0

# %%
# 출발 및 배송 건수가 가장 많은 지역
df_start_end.sort_values(by=['total'],ascending=False).head(10)
# Out:
#                    start   end   total
# 5011000078068400  3882.0  14.0  3896.0
# 5013000610049100  1790.0   0.0  1790.0
# 5013000731055200  1235.0   0.0  1235.0
# 5011000137030100  1137.0   2.0  1139.0
# 5013000821028200   731.0   0.0   731.0
# 4148000690015300   582.0   0.0   582.0
# 5013000777063100   475.0   0.0   475.0
# 5011000595017300   462.0   1.0   463.0
# 5011000213090100   454.0   3.0   457.0
# 5011000685067100   453.0   0.0   453.0

# %% [markdown]
# #### • 유통경로 분석
# ---

# %%
df.head()
# Out:
#    index             start               end   prod  cnt
# 0      0  5011000595017300  2871000192069300     음반    3
# 1      1  4148000690043300  5011000264024400  문화컨텐츠    3
# 2      2  5011000078068400  1120000007005400    농산물    3
# 3      3  4127100048006400  5011000587019400   기타식품    7
# 4      4  5011000078068400  2823700010076300    농산물    3

# %%
# 자주 배송되는 특정경로는 없는 것으로 보임
# 경로 기준으로 배차를 하는 방법은 비효율적으로 판단된다.
df_route=df.groupby(['start','end'],as_index=False)['prod'].count()
df_route.columns=['start','end','cnt']
df_route=df_route.sort_values(by=['cnt'],ascending=False)
df_route.head(10)
# Out:
#                   start               end  cnt
# 3684   4141000031030100  5013000635005300    7
# 6712   4211000650079200  5011000437052400    7
# 735    1154500001021400  5011000214025100    5
# 3664   4141000031030100  5011000596012200    5
# 6962   4374500066090200  5011000427079100    5
# 2814   4128500028049400  5011000373021200    4
# 14369  5011000228004400  4117300017043200    4
# 3536   4141000031030100  5011000318044100    4
# 6952   4374000244008400  5011000373055300    4
# 3269   4137000019060200  5011000366024400    4

# %%
#  가장 많이 배송되는 지역 > 물품이 다양하기 때문에 카테고리화도 쉽지 않겠다.
df[(df['start']==4141000031030100) & (df['end']==5013000635005300)]
# Out:
#        index             start               end     prod  cnt
# 4810    4810  4141000031030100  5013000635005300     주방용품    7
# 5657    5657  4141000031030100  5013000635005300    이미용가전    4
# 14325  14325  4141000031030100  5013000635005300     스킨케어    7
# 17413  17413  4141000031030100  5013000635005300     생활가전    3
# 19976  19976  4141000031030100  5013000635005300       음료    3
# 20177  20177  4141000031030100  5013000635005300  베이스메이크업    5
# 22653  22653  4141000031030100  5013000635005300       상의    3

# %% [markdown]
# #### • 출발지 기준 배차 분석
# ---
# * 출발기준으로 가장 많이 배송하는 물품을 대표 물품으로 선정

# %%
df[df['start']==4141000031030100].groupby('prod')['cnt'].sum().sort_values(ascending=False).head(1).reset_index()
# Out:
#    prod  cnt
# 0  건강용품  468

# %%
list_of_df=[]
for i in list(df['start'].unique()):
    loop_df=df[df['start']==i].groupby('prod')['cnt'].sum().sort_values(ascending=False).reset_index().head(1)
    loop_df['id']=i
    list_of_df.append(loop_df)

df_accum_start=pd.concat(list_of_df)

# %%
df_accum_start
# Out:
#            prod    cnt                id
# 0            음반   1652  5011000595017300
# 0         문화컨텐츠    383  4148000690043300
# 0           농산물  14380  5011000078068400
# 0          기타식품     96  4127100048006400
# 0           농산물    492  5013000778073200
# ..          ...    ...               ...
# 0        기타패션잡화      9  4113300019005400
# 0          침구세트      4  4873000294001400
# 0        기타패션잡화    105  2638000008087200
# 0   스마트디바이스액세서리      3  1120000013030100
# 0          세탁용품      4  2811000139076100
#
# [4229 rows x 3 columns]

# %%
# 물품별 전체 배송량 데이터 생성
df_prod_sum=pd.DataFrame(df.groupby('prod')['cnt'].sum()).reset_index()
df_prod_sum.columns=['prod','total']
df_prod_sum.head()
# Out:
#        prod  total
# 0  DIY자재/용품    150
# 1        PC    200
# 2    PC주변기기     30
# 3      가공식품   5766
# 4        가방     26

# %%
# 출발지 기준 물품 배송량에 left join
df_merge=pd.merge(df_accum_start,df_prod_sum,how='left',on='prod')
df_merge=df_merge[['id','prod','cnt','total']]
df_merge.head()
# Out:
#                  id   prod    cnt  total
# 0  5011000595017300     음반   1652   2357
# 1  4148000690043300  문화컨텐츠    383   5429
# 2  5011000078068400    농산물  14380  87829
# 3  4127100048006400   기타식품     96   4250
# 4  5013000778073200    농산물    492  87829

# %%
# 전체 물품 배송량중 몇 퍼센트를 싣고 떠나는지 분석을 통해 차량 배차가 가능함

df_merge['ratio']=(df_merge['cnt']/df_merge['total'])
df_merge.head()
# Out:
#                  id   prod    cnt  total     ratio
# 0  5011000595017300     음반   1652   2357  0.700891
# 1  4148000690043300  문화컨텐츠    383   5429  0.070547
# 2  5011000078068400    농산물  14380  87829  0.163727
# 3  4127100048006400   기타식품     96   4250  0.022588
# 4  5013000778073200    농산물    492  87829  0.005602

# %%
# 전체 물품중 적어도 50% 이상을 출발시키는 곳에서 틀성 배차를 하는 것이 효울적일 것이다.
df_merge[df_merge['ratio']>0.5]
# Out:
#                     id           prod   cnt  total     ratio
# 0     5011000595017300             음반  1652   2357  0.700891
# 57    4148000427007400       출산/유아동의류    23     30  0.766667
# 70    4148000690015300          문화컨텐츠  3064   5429  0.564376
# 96    1117000009037100       기타디지털/가전   837   1505  0.556146
# 359   4127300022051100        위생/건강용품   135    249  0.542169
# 457   5011000320025200           네일케어    35     69  0.507246
# 584   4873000228047300             낚시   316    386  0.818653
# 596   4150000196034300         다이어트식품   419    619  0.676898
# 1109  4117300018005400         기타패션의류  1605   3042  0.527613
# 1129  4413300143027400             신발   392    637  0.615385
# 1179  3020000121041200       선글라스/안경테    14     27  0.518519
# 1290  4122000009040300             캠핑    25     43  0.581395
# 1504  4155000331094100        기타출산/육아    12     22  0.545455
# 1813  4374500066090200  태블릿PC/노트북액세서리    25     40  0.625000
# 1927  4139000127044300        게임기/타이틀    60     87  0.689655
# 4226  2638000008087200         기타패션잡화   105    152  0.690789

# %% [markdown]
# ### **Process03**
# #### - ML 활용 유통량 예측

# %% [markdown]
# #### • 모델링을 위한 데이터 준비
# ---
# * 모델링을 수행하기 위해 Feature와 예측하고자하는 값인 Y로 데이터를 나눔
# * 학습과 예측을 위한 Train / Test set 분할

# %%
df.head()
# Out:
#    index             start               end   prod  cnt
# 0      0  5011000595017300  2871000192069300     음반    3
# 1      1  4148000690043300  5011000264024400  문화컨텐츠    3
# 2      2  5011000078068400  1120000007005400    농산물    3
# 3      3  4127100048006400  5011000587019400   기타식품    7
# 4      4  5011000078068400  2823700010076300    농산물    3

# %%
# 모델링을 학습하기 위한 Feature(X) 와 Y데이터를 구분하는 단계

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

X=df.drop(['index','cnt'],axis=1)
Y=df['cnt']

x_train,x_test,y_train,y_test=train_test_split(X, Y, test_size=0.4, random_state=1234)

print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (19010, 3)
# (19010,)
# (12674, 3)
# (12674,)

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
le.fit(list(x_train['prod'].values)+list(x_test['prod'].values))
x_train['prod']=le.transform(x_train['prod'])
x_test['prod']=le.transform(x_test['prod'])

# %%
x_test['prod'].head()
# Out:
# 30500    27
# 26517     5
# 8880     27
# 22851    27
# 25004    27
# Name: prod, dtype: int64

# %%
x_train['prod'].head()
# Out:
# 13891     3
# 9166     27
# 11955    27
# 1153     44
# 16525    27
# Name: prod, dtype: int64

# %% [markdown]
# #### **•모델 학습 및 평가**
# ---
# * 모델을 학습하고 예측을 수행하여 성능을 평가

# %%
rfr=RandomForestRegressor(n_estimators=300,max_depth=8)

rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=8, n_estimators=300)

# %%
# 예측
# 예측은 학습에 사용된 Data와 Test Data 모두 예측하고 평가함( 과적합 여부 판별)

import numpy as np
from sklearn.metrics import mean_absolute_error,r2_score

y_pred_train = rfr.predict(x_train)
y_pred_test= rfr.predict(x_test)

mae_train = mean_absolute_error(y_train,y_pred_train)
print('mae_train(mae) : ' ,mae_train)
r2_train= r2_score(y_train,y_pred_train)
print('r2_score(r2) :' , r2_train)
print('')
mae_test=mean_absolute_error(y_test,y_pred_test)
print('mae_test(mae) : ',mae_test)
r2_test=r2_score(y_test,y_pred_test)
print('r2_score(r2) : ',r2_test)
# Out:
# mae_train(mae) :  2.1998475827258845
# r2_score(r2) : 0.39244730781716863
#
# mae_test(mae) :  2.3003226258950744
# r2_score(r2) :  0.12771426676161712

# %%
pd.options.display.float_format='{:.5f}'.format
result=pd.DataFrame({'Real Values':y_test, 'Predicted Values' :y_pred_test})
result['diff'] = result['Real Values'] - result['Predicted Values']
result.head(10)
# Out:
#        Real Values  Predicted Values      diff
# 30500            4           4.06737  -0.06737
# 26517           38           5.12538  32.87462
# 8880             6           3.78160   2.21840
# 22851            3           3.79722  -0.79722
# 25004            3           4.00259  -1.00259
# 13359            5           7.67567  -2.67567
# 30867            3          16.96057 -13.96057
# 2111             3           4.50784  -1.50784
# 24626            9           4.83202   4.16798
# 20642            3           5.10658  -2.10658

# %%
result[result['diff']>20]
# Out:
#        Real Values  Predicted Values     diff
# 26517           38           5.12538 32.87462
# 16712           37           8.83714 28.16286
# 11705           93           6.06738 86.93262
# 26494           50           5.89417 44.10583
# 23922           39           5.32595 33.67405
# ...            ...               ...      ...
# 5195            43           5.08380 37.91620
# 13903           35           4.45515 30.54485
# 24912           34           9.67193 24.32807
# 27260           47           7.36504 39.63496
# 21843           26           5.76900 20.23100
#
# [125 rows x 3 columns]

# %%
# 성능이 좋지 않을땐 ? 해당 지역에 평균 배송량을 사용하는 것이 훨씬 이득인 경우가 많음
sns.scatterplot(x=result['Real Values'],y=result['Predicted Values'])
plt.xlim(0,400)
plt.ylim(0,400)

x=[0,400]
y=[0,400]
plt.plot(x,y,color='red')
plt.gcf().set_size_inches(7,7)

# %% [markdown]
# #### **• 중요 변수 파악**
# ---
# * Feature IMP 분석을 통한 중요변수 파악

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font',family='AppleGothic')
# %matplotlib inline
plt.style.use(['dark_background'])

ftr_importtances_values=rfr.feature_importances_
ftr_importtances=pd.Series(ftr_importtances_values,index=x_train.columns)
ftr_top20=ftr_importtances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature Importances')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()

# %% [markdown]
# ### · 모델 Save and Read
# ---
# * 최종 모델을 저장 및 다시 불러오기

# %%
import pickle
# 모델 저장
saved_model = pickle.dumps(rfr)

# 모델 Read
rfr_from_pickle = pickle.loads(saved_model)

# %%
# ▶ Summary
# (1) 출발지 : 4,229개소 / 도착지 : 26,875개소
# (2) 총 배송량(80%) : 출발지(상위 500개소), 도착지(상위 20,500개소)
# (3) 대표 물품 선정
#    - 가장 많이 배송하는 물품
#    - 전체 물품 배송물량 중 최소 50%이상을 배송하는 지역

# 배차를 위한 최종 데이터(feat. 취급주의 품목)
df_merge[df_merge['ratio'] > 0.50].loc[(0, 70, 96, 457, 1179, 1813, 1927),:]
# Out:
#                     id           prod   cnt  total   ratio
# 0     5011000595017300             음반  1652   2357 0.70089
# 70    4148000690015300          문화컨텐츠  3064   5429 0.56438
# 96    1117000009037100       기타디지털/가전   837   1505 0.55615
# 457   5011000320025200           네일케어    35     69 0.50725
# 1179  3020000121041200       선글라스/안경테    14     27 0.51852
# 1813  4374500066090200  태블릿PC/노트북액세서리    25     40 0.62500
# 1927  4139000127044300        게임기/타이틀    60     87 0.68966
